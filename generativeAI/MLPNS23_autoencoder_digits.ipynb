# %% [markdown]
# <a href="https://colab.research.google.com/github/massimocipressi/MLPNS_MCipressi/blob/main/generativeAI/MLPNS23_autoencoder_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential  
from keras import optimizers
from keras.layers import Dense#, Dropout, Flatten
#from keras.layers import Conv2D, MaxPooling2D
#from keras import backend as K
#import glob
import pylab as pl
from PIL import Image

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. change kernel to GPU
# go to runtime -> change runtime type -> GPU

# %% [markdown]
# # digits first

# %%
from keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

img_rows, img_cols = 28, 28
pl.imshow(x_train[0])
pl.axis('off')
intialshape = x_train[0].shape
ndim = np.prod(x_train[0].shape)
x_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
x_train.dtype, x_train.max(), x_train.min()
# Out:
# (dtype('uint8'), 255, 0)

# %%
x_train = (x_train.astype(float) / 255).reshape(len(x_train), ndim)
x_test = (x_test.astype(float) / 255).reshape(len(x_test), ndim)
x_train.shape, x_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
xshape = x_train.shape[1]

# %% [markdown]
# # create a model

# %%
keras.models?

# %%
model_digits64 = Sequential()
## encoder
model_digits64.add(Dense(256, activation='relu', input_dim=xshape))
# input layer and the output size
model_digits64.add(Dense(128, activation='relu', input_dim=xshape))
#compression layer
model_digits64.add(Dense(64, activation='relu'))
## deencoder
#decompression layer, same size as in the encoder
model_digits64.add(Dense(128, activation='relu'))
#output layer, same size as input
model_digits64.add(Dense(ndim, activation='linear'))

# %%
model_digits64 = Sequential()
## encoder
# input layer and the output size
model_digits64.add(Dense(128, activation='relu', input_dim=xshape))
#compression layer
model_digits64.add(Dense(64, activation='relu'))
## deencoder
#decompression layer, same size as in the encoder
model_digits64.add(Dense(128, activation='relu'))
#output layer, same size as input
model_digits64.add(Dense(ndim, activation='linear'))


#alternative syntax
"""
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

encoder = Model(input_img, encoded)

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
"""
# Out:
# '\nencoded = Dense(encoding_dim, activation=\'relu\')(input_img)\n# "decoded" is the lossy reconstruction of the input\ndecoded = Dense(784, activation=\'sigmoid\')(encoded)\n\nautoencoder = Model(input_img, decoded)\n\nencoder = Model(input_img, encoded)\n\n# create a placeholder for an encoded (32-dimensional) input\nencoded_input = Input(shape=(encoding_dim,))\n# retrieve the last layer of the autoencoder model\ndecoder_layer = autoencoder.layers[-1]\n# create the decoder model\ndecoder = Model(encoded_input, decoder_layer(encoded_input))\n'

# %% [markdown]
# ## losses and activation functions
#
# ### regression
# - loss='mean_squared_error' L2: default loss to use for regression problems. => linear activation function in output layer, one node out
#
# alternatives:  loss='mean_squared_logarithmic_error', 'mean_absolute_error' (which is L1 instead of L2)
# ### binary classification
#
# - loss='binary_crossentropy' => sigmoid activation function in output layer, one node out
#
# alternatives: 'hinge'
#
# ### multiclass classification
# categorical encoded as numerical
# - loss='categorical_crossentropy' => softmax n nodes out
#
# onehot encoded categoridal
# - 'parse_categorical_crossentropy' => softmax n nodes out
#
# - 'kullback Leibler Divergence Loss' => probabilistic categorical classification; log(P/Q)

# %% [markdown]
# ## optimizers
# - SGD: stocastic gradient descent
#     - nesterov=True -> momentum inclusion
# - adam: Adaptive moment estimation. **good in most cases**
# - adagrad: different steps for different parameters based on frequency (binary input) well-suited for dealing with sparse data.
#
# - adaDelta: like adagrad but compensated for vanishing learning rate problem
#
# momentum refers to looking one step back and make a decision that includes the slope there

# %% [markdown]
# ## learning Rate:
# generally you need to adjust the learning rate which is how much you change the parameters by at each step.
# keras.optimizers.Adam(lr=0.001)
#
#
# https://gitcdn.xyz/cdn/Tony607/blog_statics/e1a0b1e060e783bd1978a141acff897ae71bd021/images/optimizer/optimizer.gif

# %%
# choose the optimizer and loss appropriately!
model_digits64.compile(optimizer="adadelta", loss="mean_squared_error")

# %%
print(model_digits64.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               100480
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  dense_8 (Dense)             (None, 784)               101136
#
# =================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history64 = model_digits64.fit(x_train, x_train, 
                               validation_data=(x_test, x_test),
                               epochs=20, batch_size=100, verbose=1)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 8s 3ms/step - loss: 0.1172 - val_loss: 0.1185
# Epoch 2/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1161 - val_loss: 0.1175
# Epoch 3/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1152 - val_loss: 0.1167
# Epoch 4/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1144 - val_loss: 0.1160
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1138 - val_loss: 0.1154
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1132 - val_loss: 0.1148
# Epoch 7/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1127 - val_loss: 0.1143
# Epoch 8/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1122 - val_loss: 0.1139
# Epoch 9/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1118 - val_loss: 0.1134
# Epoch 10/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1113 - val_loss: 0.1130
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1110 - val_loss: 0.1126
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1106 - val_loss: 0.1123
# Epoch 13/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1102 - val_loss: 0.1119
# Epoch 14/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1099 - val_loss: 0.1116
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1096 - val_loss: 0.1112
# Epoch 16/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1092 - val_loss: 0.1109
# Epoch 17/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1089 - val_loss: 0.1106
# Epoch 18/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1086 - val_loss: 0.1103
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1083 - val_loss: 0.1100
# Epoch 20/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1080 - val_loss: 0.1097

# %% [markdown]
# # always look at the loss!

# %%
pl.plot(np.array(history64.history['loss']), label="training")
pl.plot(np.array(history64.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

# %% [markdown]
# The loss fuctionis plotted and because it is still decreasingn quite rapidly (slope of the curve not near 0 yet) I know I did not run enough epochs. Try and run for 200 epochs!

# %% [markdown]
# # predict

# %%
output_image64 = model_digits64.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
def compareinout(i, outim, testimg, initialshape=(28,28)):
  fig = pl.figure(figsize(10,5))
  ax = fig.add_subplot(121) 
  ax.imshow(testimg[i].reshape(initialshape) , cmap="bone")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  ax = fig.add_subplot(122) 
  ax.imshow(outim[i].reshape(initialshape) , cmap="bone")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %%
for i in range(10):
  compareinout(i, output_image64, x_test)

# %% [markdown]
# This is a rather bad result. Let me see if I can improve it . The images are too detailed. I can treat the problem as a binary problem to derice some detail. To approach a binary classifier I switch the activation function in the last layer to sigmoid

# %% [markdown]
# # train training longer

# %%
history64 = model_digits64.fit(x_train, x_train, 
                               validation_data=(x_test, x_test),
                               epochs=40, batch_size=100, verbose=1)
# Out:
# Epoch 1/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1077 - val_loss: 0.1094
# Epoch 2/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1074 - val_loss: 0.1090
# Epoch 3/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1071 - val_loss: 0.1087
# Epoch 4/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1068 - val_loss: 0.1084
# Epoch 5/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1065 - val_loss: 0.1081
# Epoch 6/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1062 - val_loss: 0.1078
# Epoch 7/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1059 - val_loss: 0.1075
# Epoch 8/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1056 - val_loss: 0.1072
# Epoch 9/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1053 - val_loss: 0.1068
# Epoch 10/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1049 - val_loss: 0.1065
# Epoch 11/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1046 - val_loss: 0.1062
# Epoch 12/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1043 - val_loss: 0.1059
# Epoch 13/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1040 - val_loss: 0.1055
# Epoch 14/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1036 - val_loss: 0.1052
# Epoch 15/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1033 - val_loss: 0.1048
# Epoch 16/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1029 - val_loss: 0.1044
# Epoch 17/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1026 - val_loss: 0.1041
# Epoch 18/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1022 - val_loss: 0.1037
# Epoch 19/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1019 - val_loss: 0.1033
# Epoch 20/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1015 - val_loss: 0.1029
# Epoch 21/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1011 - val_loss: 0.1025
# Epoch 22/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1007 - val_loss: 0.1021
# Epoch 23/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1003 - val_loss: 0.1017
# Epoch 24/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0999 - val_loss: 0.1013
# Epoch 25/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0995 - val_loss: 0.1009
# Epoch 26/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0991 - val_loss: 0.1004
# Epoch 27/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0987 - val_loss: 0.1000
# Epoch 28/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0982 - val_loss: 0.0995
# Epoch 29/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0978 - val_loss: 0.0991
# Epoch 30/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0973 - val_loss: 0.0986
# Epoch 31/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0969 - val_loss: 0.0981
# Epoch 32/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0964 - val_loss: 0.0976
# Epoch 33/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0959 - val_loss: 0.0971
# Epoch 34/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 35/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0950 - val_loss: 0.0961
# Epoch 36/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0945 - val_loss: 0.0956
# Epoch 37/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0940 - val_loss: 0.0951
# Epoch 38/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0935 - val_loss: 0.0945
# Epoch 39/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0929 - val_loss: 0.0940
# Epoch 40/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0924 - val_loss: 0.0935

# %% [markdown]
# ## earlystopping call back

# %%
from keras.callbacks import EarlyStopping
callback = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.0001)
# This callback will stop the training when there is no improvement in
# the loss for 5 consecutive epochs.
history64 = model_digits64.fit(x_train, x_train, 
                               validation_data=(x_test, x_test),
                               epochs=80, batch_size=100, 
                               verbose=1, callbacks=[callback])
# Out:
# Epoch 1/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0919 - val_loss: 0.0929
# Epoch 2/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0914 - val_loss: 0.0923
# Epoch 3/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0908 - val_loss: 0.0918
# Epoch 4/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0903 - val_loss: 0.0912
# Epoch 5/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0897 - val_loss: 0.0906
# Epoch 6/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0892 - val_loss: 0.0900
# Epoch 7/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0886 - val_loss: 0.0895
# Epoch 8/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0880 - val_loss: 0.0889
# Epoch 9/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0875 - val_loss: 0.0883
# Epoch 10/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0869 - val_loss: 0.0877
# Epoch 11/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0863 - val_loss: 0.0871
# Epoch 12/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0858 - val_loss: 0.0865
# Epoch 13/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0852 - val_loss: 0.0859
# Epoch 14/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0847 - val_loss: 0.0854
# Epoch 15/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0841 - val_loss: 0.0848
# Epoch 16/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0835 - val_loss: 0.0842
# Epoch 17/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0830 - val_loss: 0.0836
# Epoch 18/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0824 - val_loss: 0.0831
# Epoch 19/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0819 - val_loss: 0.0825
# Epoch 20/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0814 - val_loss: 0.0819
# Epoch 21/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0808 - val_loss: 0.0814
# Epoch 22/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0803 - val_loss: 0.0808
# Epoch 23/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0798 - val_loss: 0.0803
# Epoch 24/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0793 - val_loss: 0.0798
# Epoch 25/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0788 - val_loss: 0.0792
# Epoch 26/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0783 - val_loss: 0.0787
# Epoch 27/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0778 - val_loss: 0.0782
# Epoch 28/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0773 - val_loss: 0.0777
# Epoch 29/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0769 - val_loss: 0.0773
# Epoch 30/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0764 - val_loss: 0.0768
# Epoch 31/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0760 - val_loss: 0.0763
# Epoch 32/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0755 - val_loss: 0.0759
# Epoch 33/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0751 - val_loss: 0.0755
# Epoch 34/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0747 - val_loss: 0.0750
# Epoch 35/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0743 - val_loss: 0.0746
# Epoch 36/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0739 - val_loss: 0.0742
# Epoch 37/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0735 - val_loss: 0.0738
# Epoch 38/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0732 - val_loss: 0.0734
# Epoch 39/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0728 - val_loss: 0.0731
# Epoch 40/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0724 - val_loss: 0.0727
# Epoch 41/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0721 - val_loss: 0.0724
# Epoch 42/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0718 - val_loss: 0.0720
# Epoch 43/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0715 - val_loss: 0.0717
# Epoch 44/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0712 - val_loss: 0.0714
# Epoch 45/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0709 - val_loss: 0.0711
# Epoch 46/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0706 - val_loss: 0.0708
# Epoch 47/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0703 - val_loss: 0.0705
# Epoch 48/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0701 - val_loss: 0.0703
# Epoch 49/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0698 - val_loss: 0.0700
# Epoch 50/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0696 - val_loss: 0.0697
# Epoch 51/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0693 - val_loss: 0.0695
# Epoch 52/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0691 - val_loss: 0.0693
# Epoch 53/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0689 - val_loss: 0.0690
# Epoch 54/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0687 - val_loss: 0.0688
# Epoch 55/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0685 - val_loss: 0.0686
# Epoch 56/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0683 - val_loss: 0.0684
# Epoch 57/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0681 - val_loss: 0.0682
# Epoch 58/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0679 - val_loss: 0.0680
# Epoch 59/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0677 - val_loss: 0.0679
# Epoch 60/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0676 - val_loss: 0.0677
# Epoch 61/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0674 - val_loss: 0.0675
# Epoch 62/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0672 - val_loss: 0.0674
# Epoch 63/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0671 - val_loss: 0.0672
# Epoch 64/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0670 - val_loss: 0.0671
# Epoch 65/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0668 - val_loss: 0.0669
# Epoch 66/80
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0667 - val_loss: 0.0668
# Epoch 67/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0666 - val_loss: 0.0667
# Epoch 68/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0665 - val_loss: 0.0666
# Epoch 69/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0663 - val_loss: 0.0664
# Epoch 70/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0662 - val_loss: 0.0663
# Epoch 71/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0661 - val_loss: 0.0662
# Epoch 72/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0660 - val_loss: 0.0661
# Epoch 73/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0659 - val_loss: 0.0660
# Epoch 74/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0658 - val_loss: 0.0659
# Epoch 75/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0657 - val_loss: 0.0658
# Epoch 76/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0657 - val_loss: 0.0657
# Epoch 77/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0656 - val_loss: 0.0657
# Epoch 78/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0655 - val_loss: 0.0656
# Epoch 79/80
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0654 - val_loss: 0.0655
# Epoch 80/80
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0653 - val_loss: 0.0654

# %%
pl.plot(np.array(history64.history['loss']), label="training")
pl.plot(np.array(history64.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

# %%
output_image64 = model_digits64.predict(x_test)
for i in range(10):
  compareinout(i, output_image64, x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## posterior collapse: the autoencoder learned the average of the data

# %% [markdown]
# # change the learning rate

# %%
from tensorflow import keras
from keras import optimizers
opt = keras.optimizers.Adam(learning_rate=0.01)
model_digits64.compile(loss="mean_squared_error", optimizer=opt)
history64 = model_digits64.fit(x_train, x_train, 
                               validation_data=(x_test, x_test),
                               epochs=20, batch_size=100, verbose=1)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 3s 3ms/step - loss: 0.0272 - val_loss: 0.0205
# Epoch 2/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0195 - val_loss: 0.0186
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0184 - val_loss: 0.0175
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0175 - val_loss: 0.0176
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0167 - val_loss: 0.0164
# Epoch 7/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 8/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0165 - val_loss: 0.0158
# Epoch 9/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0164 - val_loss: 0.0161
# Epoch 10/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0162 - val_loss: 0.0163
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0163 - val_loss: 0.0161
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0162 - val_loss: 0.0159
# Epoch 13/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0162 - val_loss: 0.0166
# Epoch 14/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 15/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0162 - val_loss: 0.0163
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 17/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 18/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0160 - val_loss: 0.0156
# Epoch 19/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0161 - val_loss: 0.0157
# Epoch 20/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0160 - val_loss: 0.0157

# %%
output_image64 = model_digits64.predict(x_test)
pl.plot(np.array(history64.history['loss']), label="training")
pl.plot(np.array(history64.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()

#pl.yscale('log')
#pl.xscale('log')
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# A noisier loss function is not a bad sign! the model is overall learning - decreasing the learning rate would give a smoother loss

# %%
for i in range(10):
  compareinout(i, output_image64, x_test)

# %% [markdown]
# # change activation function on the last layer

# %%
model_digits64_sig = Sequential()
## encoder
# input layer and the output size
model_digits64_sig.add(Dense(128, activation='relu', input_dim=xshape))
#compression layer
model_digits64_sig.add(Dense(64, activation='relu'))
## deencoder
#decompression layer, same size as in the encoder
model_digits64_sig.add(Dense(128, activation='relu'))
#output layer, same size as input
model_digits64_sig.add(Dense(ndim, activation='sigmoid'))

opt = keras.optimizers.Adam(learning_rate=0.001)
model_digits64_sig.compile(loss="mean_squared_error", optimizer=opt)
history64_sig = model_digits64_sig.fit(x_train, x_train, 
                               validation_data=(x_test, x_test),
                               epochs=40, batch_size=100, verbose=1,
                               callbacks=[callback])
# Out:
# Epoch 1/40
# 600/600 [==============================] - 4s 4ms/step - loss: 0.0362 - val_loss: 0.0169
# Epoch 2/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0141 - val_loss: 0.0115
# Epoch 3/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0107 - val_loss: 0.0098
# Epoch 4/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0092 - val_loss: 0.0082
# Epoch 5/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 6/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 7/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 8/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 9/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 10/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 11/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 12/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 13/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 14/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 15/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 16/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 17/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 18/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 19/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 20/40
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 21/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 22/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 23/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 24/40
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 25/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 26/40
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 27/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 28/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 29/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 30/40
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0043 - val_loss: 0.0043

# %%
pl.plot(np.array(history64_sig.history['loss']), label="training")
pl.plot(np.array(history64_sig.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

# %% [markdown]
# The loss function got quite flat. This model has converged (or nearly so)

# %%
output_image64_sig = model_digits64_sig.predict(x_test)
for i in range(10):
  compareinout(i, output_image64_sig, x_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# Much better! Let me choose a loss fuction that is more appropriate for a binary classificaton - this is not a binary task but the gradient in the data is significant.

# %%
# sigmoid and binary cross entropy loss
model_digits64_bce = model_digits64_sig

# %%
opt = keras.optimizers.Adadelta(learning_rate=0.1)
model_digits64_bce.compile(optimizer=opt, loss="binary_crossentropy")
history64_bce = model_digits64_bce.fit(x_train, x_train, 
                                       validation_data=(x_test, x_test), 
                                       epochs=20, batch_size=100, verbose=1, 
                                       callbacks=[callback])
# Out:
# Epoch 1/20
# 600/600 [==============================] - 4s 4ms/step - loss: 0.0749 - val_loss: 0.0743
# Epoch 2/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0747 - val_loss: 0.0742
# Epoch 3/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0746 - val_loss: 0.0741
# Epoch 4/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0745 - val_loss: 0.0741
# Epoch 5/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0745 - val_loss: 0.0741
# Epoch 6/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0745 - val_loss: 0.0740
# Epoch 7/20
# 600/600 [==============================] - 2s 4ms/step - loss: 0.0744 - val_loss: 0.0740
# Epoch 8/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0744 - val_loss: 0.0740
# Epoch 9/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0744 - val_loss: 0.0740
# Epoch 10/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 11/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 12/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 13/20
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 14/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 15/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0743 - val_loss: 0.0739
# Epoch 16/20
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0742 - val_loss: 0.0738

# %%
pl.plot(np.array(history64_bce.history['loss']), label="training")
pl.plot(np.array(history64_bce.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

# %% [markdown]
# This loss fuction is also decreasing steeply. Too few epochs!

# %%
output_image64_bce =  v.predict(x_test)
for i in range(10):
  compareinout(i, output_image64_bce, x_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %% [markdown]
# This is a pretty good result!

# %% [markdown]
# # try more compression
#
# Now we shrink the bottle neck to 16 neurons: a much more ambitions model!

# %%
model_digits16 = Sequential()
#encoder
model_digits16.add(Dense(128, activation='relu', input_dim=xshape))
model_digits16.add(Dense(64, activation='relu'))
model_digits16.add(Dense(32, activation='relu'))
#bottle neck
model_digits16.add(Dense(16, activation='relu'))
#decoder
model_digits16.add(Dense(32, activation='relu'))
model_digits16.add(Dense(64, activation='relu'))
model_digits16.add(Dense(128, activation='relu'))
model_digits16.add(Dense(xshape, activation='sigmoid'))

# %%
opt = keras.optimizers.Adadelta(learning_rate=0.1)
model_digits16.compile(optimizer=opt, loss="binary_crossentropy")

# %%
print(model_digits16.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 128)               100480
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  dense_16 (Dense)            (None, 16)                528
#
#  dense_17 (Dense)            (None, 32)                544
#
#  dense_18 (Dense)            (None, 64)                2112
#
#  dense_19 (Dense)            (None, 128)               8320
#
#  dense_20 (Dense)            (None, 784)               101136
#
# =================================================================
# Total params: 223,456
# Trainable params: 223,456
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history16_bce = model_digits16.fit(x_train, x_train, 
                           validation_data=(x_test, x_test),
                           epochs=200, batch_size=100, 
                           verbose=1)
# Out:
# Epoch 1/200
# 600/600 [==============================] - 5s 4ms/step - loss: 0.5823 - val_loss: 0.2752
# Epoch 2/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2682 - val_loss: 0.2644
# Epoch 3/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2624 - val_loss: 0.2601
# Epoch 4/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2586 - val_loss: 0.2566
# Epoch 5/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2556 - val_loss: 0.2540
# Epoch 6/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2535 - val_loss: 0.2525
# Epoch 7/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2522 - val_loss: 0.2515
# Epoch 8/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2514 - val_loss: 0.2509
# Epoch 9/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2509 - val_loss: 0.2503
# Epoch 10/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 11/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2499 - val_loss: 0.2496
# Epoch 12/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2494 - val_loss: 0.2489
# Epoch 13/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2484 - val_loss: 0.2474
# Epoch 14/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2465 - val_loss: 0.2446
# Epoch 15/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2427 - val_loss: 0.2404
# Epoch 16/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2384 - val_loss: 0.2361
# Epoch 17/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2345 - val_loss: 0.2323
# Epoch 18/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2312 - val_loss: 0.2294
# Epoch 19/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2286 - val_loss: 0.2270
# Epoch 20/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2266 - val_loss: 0.2252
# Epoch 21/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2250 - val_loss: 0.2237
# Epoch 22/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2238 - val_loss: 0.2225
# Epoch 23/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2228 - val_loss: 0.2216
# Epoch 24/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2217 - val_loss: 0.2204
# Epoch 25/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2206 - val_loss: 0.2191
# Epoch 26/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.2192 - val_loss: 0.2172
# Epoch 27/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2168 - val_loss: 0.2137
# Epoch 28/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2124 - val_loss: 0.2082
# Epoch 29/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2068 - val_loss: 0.2028
# Epoch 30/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2024 - val_loss: 0.1991
# Epoch 31/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1991 - val_loss: 0.1963
# Epoch 32/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1962 - val_loss: 0.1931
# Epoch 33/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1927 - val_loss: 0.1894
# Epoch 34/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1890 - val_loss: 0.1862
# Epoch 35/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1863 - val_loss: 0.1839
# Epoch 36/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1843 - val_loss: 0.1820
# Epoch 37/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1828 - val_loss: 0.1806
# Epoch 38/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1814 - val_loss: 0.1793
# Epoch 39/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1802 - val_loss: 0.1782
# Epoch 40/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1791 - val_loss: 0.1772
# Epoch 41/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1780 - val_loss: 0.1762
# Epoch 42/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1770 - val_loss: 0.1751
# Epoch 43/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1759 - val_loss: 0.1740
# Epoch 44/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1747 - val_loss: 0.1728
# Epoch 45/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1735 - val_loss: 0.1716
# Epoch 46/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1722 - val_loss: 0.1702
# Epoch 47/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1709 - val_loss: 0.1690
# Epoch 48/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1697 - val_loss: 0.1678
# Epoch 49/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1686 - val_loss: 0.1669
# Epoch 50/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1676 - val_loss: 0.1659
# Epoch 51/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1667 - val_loss: 0.1651
# Epoch 52/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1658 - val_loss: 0.1642
# Epoch 53/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1650 - val_loss: 0.1634
# Epoch 54/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1642 - val_loss: 0.1626
# Epoch 55/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1634 - val_loss: 0.1618
# Epoch 56/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1626 - val_loss: 0.1609
# Epoch 57/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1616 - val_loss: 0.1599
# Epoch 58/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1606 - val_loss: 0.1588
# Epoch 59/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1594 - val_loss: 0.1576
# Epoch 60/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1583 - val_loss: 0.1565
# Epoch 61/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1573 - val_loss: 0.1554
# Epoch 62/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1564 - val_loss: 0.1546
# Epoch 63/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1556 - val_loss: 0.1538
# Epoch 64/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1549 - val_loss: 0.1531
# Epoch 65/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1542 - val_loss: 0.1525
# Epoch 66/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1536 - val_loss: 0.1519
# Epoch 67/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1530 - val_loss: 0.1513
# Epoch 68/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1525 - val_loss: 0.1509
# Epoch 69/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1520 - val_loss: 0.1504
# Epoch 70/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1516 - val_loss: 0.1499
# Epoch 71/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1511 - val_loss: 0.1495
# Epoch 72/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1507 - val_loss: 0.1491
# Epoch 73/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1503 - val_loss: 0.1489
# Epoch 74/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1499 - val_loss: 0.1483
# Epoch 75/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1495 - val_loss: 0.1482
# Epoch 76/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1492 - val_loss: 0.1479
# Epoch 77/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1488 - val_loss: 0.1472
# Epoch 78/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1485 - val_loss: 0.1469
# Epoch 79/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1481 - val_loss: 0.1466
# Epoch 80/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1478 - val_loss: 0.1463
# Epoch 81/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1475 - val_loss: 0.1460
# Epoch 82/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1471 - val_loss: 0.1456
# Epoch 83/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1468 - val_loss: 0.1453
# Epoch 84/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1464 - val_loss: 0.1450
# Epoch 85/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1461 - val_loss: 0.1447
# Epoch 86/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1457 - val_loss: 0.1442
# Epoch 87/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1454 - val_loss: 0.1440
# Epoch 88/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1450 - val_loss: 0.1435
# Epoch 89/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1446 - val_loss: 0.1431
# Epoch 90/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1442 - val_loss: 0.1426
# Epoch 91/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1437 - val_loss: 0.1422
# Epoch 92/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1433 - val_loss: 0.1417
# Epoch 93/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1429 - val_loss: 0.1415
# Epoch 94/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1425 - val_loss: 0.1412
# Epoch 95/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1422 - val_loss: 0.1406
# Epoch 96/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1418 - val_loss: 0.1403
# Epoch 97/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1415 - val_loss: 0.1400
# Epoch 98/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1412 - val_loss: 0.1399
# Epoch 99/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1409 - val_loss: 0.1396
# Epoch 100/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1406 - val_loss: 0.1392
# Epoch 101/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1404 - val_loss: 0.1391
# Epoch 102/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1401 - val_loss: 0.1386
# Epoch 103/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1399 - val_loss: 0.1383
# Epoch 104/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1396 - val_loss: 0.1382
# Epoch 105/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1394 - val_loss: 0.1377
# Epoch 106/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1392 - val_loss: 0.1377
# Epoch 107/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1389 - val_loss: 0.1374
# Epoch 108/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1387 - val_loss: 0.1372
# Epoch 109/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1385 - val_loss: 0.1368
# Epoch 110/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1382 - val_loss: 0.1367
# Epoch 111/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1380 - val_loss: 0.1364
# Epoch 112/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1378 - val_loss: 0.1365
# Epoch 113/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1376 - val_loss: 0.1360
# Epoch 114/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1374 - val_loss: 0.1358
# Epoch 115/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1372 - val_loss: 0.1357
# Epoch 116/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1370 - val_loss: 0.1353
# Epoch 117/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1367 - val_loss: 0.1352
# Epoch 118/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1365 - val_loss: 0.1353
# Epoch 119/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1363 - val_loss: 0.1346
# Epoch 120/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1361 - val_loss: 0.1346
# Epoch 121/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1359 - val_loss: 0.1345
# Epoch 122/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1356 - val_loss: 0.1340
# Epoch 123/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1354 - val_loss: 0.1339
# Epoch 124/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1352 - val_loss: 0.1337
# Epoch 125/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1350 - val_loss: 0.1333
# Epoch 126/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1348 - val_loss: 0.1330
# Epoch 127/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1345 - val_loss: 0.1330
# Epoch 128/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1343 - val_loss: 0.1327
# Epoch 129/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1340 - val_loss: 0.1324
# Epoch 130/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1338 - val_loss: 0.1321
# Epoch 131/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1335 - val_loss: 0.1319
# Epoch 132/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1333 - val_loss: 0.1317
# Epoch 133/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1330 - val_loss: 0.1317
# Epoch 134/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1327 - val_loss: 0.1310
# Epoch 135/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1324 - val_loss: 0.1306
# Epoch 136/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1321 - val_loss: 0.1304
# Epoch 137/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1318 - val_loss: 0.1303
# Epoch 138/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1316 - val_loss: 0.1299
# Epoch 139/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1313 - val_loss: 0.1299
# Epoch 140/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1310 - val_loss: 0.1296
# Epoch 141/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1308 - val_loss: 0.1294
# Epoch 142/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1306 - val_loss: 0.1289
# Epoch 143/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1304 - val_loss: 0.1289
# Epoch 144/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1302 - val_loss: 0.1284
# Epoch 145/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1300 - val_loss: 0.1285
# Epoch 146/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1298 - val_loss: 0.1281
# Epoch 147/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1296 - val_loss: 0.1281
# Epoch 148/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1294 - val_loss: 0.1278
# Epoch 149/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1292 - val_loss: 0.1276
# Epoch 150/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1291 - val_loss: 0.1274
# Epoch 151/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1289 - val_loss: 0.1271
# Epoch 152/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1287 - val_loss: 0.1270
# Epoch 153/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1285 - val_loss: 0.1271
# Epoch 154/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1284 - val_loss: 0.1271
# Epoch 155/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1282 - val_loss: 0.1269
# Epoch 156/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1281 - val_loss: 0.1269
# Epoch 157/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1280 - val_loss: 0.1266
# Epoch 158/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1278 - val_loss: 0.1263
# Epoch 159/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1276 - val_loss: 0.1264
# Epoch 160/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1275 - val_loss: 0.1259
# Epoch 161/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1274 - val_loss: 0.1257
# Epoch 162/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1272 - val_loss: 0.1259
# Epoch 163/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1271 - val_loss: 0.1257
# Epoch 164/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1270 - val_loss: 0.1255
# Epoch 165/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1268 - val_loss: 0.1255
# Epoch 166/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1267 - val_loss: 0.1252
# Epoch 167/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1266 - val_loss: 0.1251
# Epoch 168/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1265 - val_loss: 0.1253
# Epoch 169/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1263 - val_loss: 0.1249
# Epoch 170/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1262 - val_loss: 0.1246
# Epoch 171/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1261 - val_loss: 0.1247
# Epoch 172/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1260 - val_loss: 0.1246
# Epoch 173/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1259 - val_loss: 0.1245
# Epoch 174/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1258 - val_loss: 0.1243
# Epoch 175/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1257 - val_loss: 0.1243
# Epoch 176/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1255 - val_loss: 0.1242
# Epoch 177/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1254 - val_loss: 0.1243
# Epoch 178/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1253 - val_loss: 0.1239
# Epoch 179/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1252 - val_loss: 0.1242
# Epoch 180/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1251 - val_loss: 0.1236
# Epoch 181/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1250 - val_loss: 0.1237
# Epoch 182/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1249 - val_loss: 0.1234
# Epoch 183/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1248 - val_loss: 0.1233
# Epoch 184/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1247 - val_loss: 0.1233
# Epoch 185/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1246 - val_loss: 0.1232
# Epoch 186/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1245 - val_loss: 0.1230
# Epoch 187/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1244 - val_loss: 0.1231
# Epoch 188/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1243 - val_loss: 0.1231
# Epoch 189/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1242 - val_loss: 0.1230
# Epoch 190/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1242 - val_loss: 0.1228
# Epoch 191/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1240 - val_loss: 0.1226
# Epoch 192/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1240 - val_loss: 0.1226
# Epoch 193/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1239 - val_loss: 0.1224
# Epoch 194/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1238 - val_loss: 0.1226
# Epoch 195/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1237 - val_loss: 0.1226
# Epoch 196/200
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1236 - val_loss: 0.1223
# Epoch 197/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1235 - val_loss: 0.1220
# Epoch 198/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1234 - val_loss: 0.1221
# Epoch 199/200
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1233 - val_loss: 0.1219
# Epoch 200/200
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1233 - val_loss: 0.1220

# %%
pl.plot(np.array(history16_bce.history['loss']), label="training")
pl.plot(np.array(history16_bce.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

# %%
history16_bce = model_digits16.fit(x_train, x_train, 
                           validation_data=(x_test, x_test),
                           epochs=2000, batch_size=100, 
                           verbose=1, callbacks=[callback])
# Out:
# Epoch 1/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1232 - val_loss: 0.1218
# Epoch 2/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1231 - val_loss: 0.1220
# Epoch 3/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1230 - val_loss: 0.1217
# Epoch 4/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1229 - val_loss: 0.1218
# Epoch 5/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1228 - val_loss: 0.1217
# Epoch 6/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1227 - val_loss: 0.1215
# Epoch 7/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1226 - val_loss: 0.1216
# Epoch 8/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1226 - val_loss: 0.1212
# Epoch 9/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1225 - val_loss: 0.1211
# Epoch 10/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1224 - val_loss: 0.1210
# Epoch 11/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1223 - val_loss: 0.1211
# Epoch 12/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1222 - val_loss: 0.1211
# Epoch 13/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1222 - val_loss: 0.1209
# Epoch 14/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1221 - val_loss: 0.1210
# Epoch 15/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1220 - val_loss: 0.1208
# Epoch 16/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1219 - val_loss: 0.1207
# Epoch 17/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1219 - val_loss: 0.1206
# Epoch 18/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1218 - val_loss: 0.1206
# Epoch 19/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1217 - val_loss: 0.1205
# Epoch 20/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1216 - val_loss: 0.1205
# Epoch 21/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1215 - val_loss: 0.1204
# Epoch 22/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1215 - val_loss: 0.1203
# Epoch 23/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1214 - val_loss: 0.1204
# Epoch 24/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1213 - val_loss: 0.1201
# Epoch 25/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1212 - val_loss: 0.1199
# Epoch 26/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1212 - val_loss: 0.1199
# Epoch 27/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1211 - val_loss: 0.1199
# Epoch 28/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1210 - val_loss: 0.1196
# Epoch 29/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1209 - val_loss: 0.1198
# Epoch 30/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1208 - val_loss: 0.1196
# Epoch 31/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1208 - val_loss: 0.1196
# Epoch 32/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1207 - val_loss: 0.1195
# Epoch 33/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1206 - val_loss: 0.1193
# Epoch 34/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1205 - val_loss: 0.1195
# Epoch 35/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1204 - val_loss: 0.1194
# Epoch 36/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1203 - val_loss: 0.1191
# Epoch 37/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1203 - val_loss: 0.1195
# Epoch 38/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1202 - val_loss: 0.1191
# Epoch 39/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1201 - val_loss: 0.1190
# Epoch 40/2000
# 600/600 [==============================] - 5s 8ms/step - loss: 0.1200 - val_loss: 0.1190
# Epoch 41/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1199 - val_loss: 0.1190
# Epoch 42/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1199 - val_loss: 0.1187
# Epoch 43/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1198 - val_loss: 0.1186
# Epoch 44/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1197 - val_loss: 0.1185
# Epoch 45/2000
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1197 - val_loss: 0.1186
# Epoch 46/2000
# 600/600 [==============================] - 5s 8ms/step - loss: 0.1195 - val_loss: 0.1184
# Epoch 47/2000
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1195 - val_loss: 0.1183
# Epoch 48/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1194 - val_loss: 0.1181
# Epoch 49/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1193 - val_loss: 0.1181
# Epoch 50/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1192 - val_loss: 0.1185
# Epoch 51/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1192 - val_loss: 0.1179
# Epoch 52/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1191 - val_loss: 0.1178
# Epoch 53/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1190 - val_loss: 0.1177
# Epoch 54/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1189 - val_loss: 0.1177
# Epoch 55/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1188 - val_loss: 0.1176
# Epoch 56/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1188 - val_loss: 0.1175
# Epoch 57/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1187 - val_loss: 0.1176
# Epoch 58/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1186 - val_loss: 0.1175
# Epoch 59/2000
# 600/600 [==============================] - 5s 8ms/step - loss: 0.1185 - val_loss: 0.1173
# Epoch 60/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1185 - val_loss: 0.1174
# Epoch 61/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1184 - val_loss: 0.1171
# Epoch 62/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1183 - val_loss: 0.1171
# Epoch 63/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1183 - val_loss: 0.1170
# Epoch 64/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1182 - val_loss: 0.1172
# Epoch 65/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1181 - val_loss: 0.1171
# Epoch 66/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1181 - val_loss: 0.1171
# Epoch 67/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1180 - val_loss: 0.1169
# Epoch 68/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1180 - val_loss: 0.1168
# Epoch 69/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1178 - val_loss: 0.1167
# Epoch 70/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1178 - val_loss: 0.1168
# Epoch 71/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1177 - val_loss: 0.1167
# Epoch 72/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1177 - val_loss: 0.1167
# Epoch 73/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1176 - val_loss: 0.1164
# Epoch 74/2000
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1176 - val_loss: 0.1164
# Epoch 75/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1175 - val_loss: 0.1164
# Epoch 76/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1174 - val_loss: 0.1164
# Epoch 77/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1174 - val_loss: 0.1162
# Epoch 78/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1173 - val_loss: 0.1162
# Epoch 79/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1173 - val_loss: 0.1160
# Epoch 80/2000
# 600/600 [==============================] - 6s 9ms/step - loss: 0.1172 - val_loss: 0.1163
# Epoch 81/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1172 - val_loss: 0.1160
# Epoch 82/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1171 - val_loss: 0.1160
# Epoch 83/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1170 - val_loss: 0.1159
# Epoch 84/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1170 - val_loss: 0.1158
# Epoch 85/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1169 - val_loss: 0.1157
# Epoch 86/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1169 - val_loss: 0.1157
# Epoch 87/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1168 - val_loss: 0.1158
# Epoch 88/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1167 - val_loss: 0.1158
# Epoch 89/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1167 - val_loss: 0.1155
# Epoch 90/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1167 - val_loss: 0.1156
# Epoch 91/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1166 - val_loss: 0.1155
# Epoch 92/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1165 - val_loss: 0.1155
# Epoch 93/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1165 - val_loss: 0.1155
# Epoch 94/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1164 - val_loss: 0.1153
# Epoch 95/2000
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1164 - val_loss: 0.1153
# Epoch 96/2000
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1163 - val_loss: 0.1152
# Epoch 97/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1163 - val_loss: 0.1152
# Epoch 98/2000
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1162 - val_loss: 0.1151
# Epoch 99/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1162 - val_loss: 0.1151
# Epoch 100/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1161 - val_loss: 0.1150
# Epoch 101/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1161 - val_loss: 0.1155
# Epoch 102/2000
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1160 - val_loss: 0.1152
# Epoch 103/2000
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1160 - val_loss: 0.1151

# %% [markdown]
# the loss fuction: once again it did not finish learning.

# %%
output_image = model_digits16.predict(x_test)

for i in range(10):
  compareinout(i, output_image, x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# The result is not bad! The decoder can recreate the image from only 16 numbers!

# %% [markdown]
# # Extract feature

# %%
from keras import backend as K
# input placeholder
inp = model_digits16.input                   
# extract the bottle neck outputs
outputs = model_digits16.layers[3].output     
# create a function to evaluate the output of the bottle neck layer for a given input
functors = K.function([inp], [outputs])    

# Testing
layer_outs = functors(x_test[:1])
pl.imshow(layer_outs[0]);

# %% [markdown]
# This is the reducted representation of the first image in the test sample: a 16-values representation of the NxN pixel image

# %%
def compareinout_encoded(i, outim, testimg, initialshape=(28,28)):
  fig = pl.figure(figsize(10,5))
  ax = fig.add_subplot(131) 
  ax.imshow(testimg[i].reshape(initialshape) , cmap="bone")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  ax = fig.add_subplot(132)
  pl.imshow(functors(testimg[i:i+1])[0])
  pl.yticks([])
  ax = fig.add_subplot(133) 
  ax.imshow(outim[i].reshape(initialshape) , cmap="bone")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %%
for i in range(10):
  compareinout_encoded(i, output_image, x_test)

# %% [markdown]
# left: original image
#
# center: compressed representation
#
# right: predicted image

# %% [markdown]
# # None of these models overfit. lets overfit them on purpose

# %%
history16_overfit = model_digits16.fit(x_train, x_train, 
                                       validation_data=(x_test, x_test), 
                                       epochs=400, batch_size=100, verbose=1)
# Out:
# Epoch 1/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1159 - val_loss: 0.1151
# Epoch 2/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1159 - val_loss: 0.1150
# Epoch 3/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1158 - val_loss: 0.1148
# Epoch 4/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1158 - val_loss: 0.1148
# Epoch 5/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1158 - val_loss: 0.1147
# Epoch 6/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1157 - val_loss: 0.1145
# Epoch 7/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1156 - val_loss: 0.1145
# Epoch 8/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1156 - val_loss: 0.1144
# Epoch 9/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1155 - val_loss: 0.1145
# Epoch 10/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1155 - val_loss: 0.1144
# Epoch 11/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1154 - val_loss: 0.1144
# Epoch 12/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1154 - val_loss: 0.1144
# Epoch 13/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1154 - val_loss: 0.1143
# Epoch 14/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1153 - val_loss: 0.1145
# Epoch 15/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1153 - val_loss: 0.1144
# Epoch 16/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1152 - val_loss: 0.1141
# Epoch 17/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1152 - val_loss: 0.1141
# Epoch 18/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1151 - val_loss: 0.1141
# Epoch 19/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1151 - val_loss: 0.1141
# Epoch 20/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1151 - val_loss: 0.1145
# Epoch 21/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1150 - val_loss: 0.1139
# Epoch 22/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1150 - val_loss: 0.1141
# Epoch 23/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1149 - val_loss: 0.1138
# Epoch 24/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1149 - val_loss: 0.1137
# Epoch 25/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1148 - val_loss: 0.1139
# Epoch 26/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1148 - val_loss: 0.1139
# Epoch 27/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1147 - val_loss: 0.1138
# Epoch 28/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1147 - val_loss: 0.1138
# Epoch 29/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1147 - val_loss: 0.1137
# Epoch 30/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1146 - val_loss: 0.1137
# Epoch 31/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1146 - val_loss: 0.1137
# Epoch 32/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1145 - val_loss: 0.1137
# Epoch 33/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1145 - val_loss: 0.1136
# Epoch 34/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1145 - val_loss: 0.1135
# Epoch 35/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1144 - val_loss: 0.1135
# Epoch 36/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1144 - val_loss: 0.1135
# Epoch 37/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1143 - val_loss: 0.1133
# Epoch 38/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1143 - val_loss: 0.1133
# Epoch 39/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1142 - val_loss: 0.1134
# Epoch 40/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1142 - val_loss: 0.1136
# Epoch 41/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1142 - val_loss: 0.1133
# Epoch 42/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1141 - val_loss: 0.1133
# Epoch 43/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1141 - val_loss: 0.1130
# Epoch 44/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1140 - val_loss: 0.1131
# Epoch 45/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1140 - val_loss: 0.1129
# Epoch 46/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1139 - val_loss: 0.1129
# Epoch 47/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1139 - val_loss: 0.1129
# Epoch 48/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1138 - val_loss: 0.1129
# Epoch 49/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1138 - val_loss: 0.1127
# Epoch 50/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1137 - val_loss: 0.1130
# Epoch 51/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1137 - val_loss: 0.1128
# Epoch 52/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1136 - val_loss: 0.1125
# Epoch 53/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1136 - val_loss: 0.1124
# Epoch 54/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1135 - val_loss: 0.1125
# Epoch 55/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1134 - val_loss: 0.1126
# Epoch 56/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1134 - val_loss: 0.1123
# Epoch 57/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1133 - val_loss: 0.1123
# Epoch 58/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1133 - val_loss: 0.1124
# Epoch 59/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1132 - val_loss: 0.1123
# Epoch 60/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1131 - val_loss: 0.1120
# Epoch 61/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1131 - val_loss: 0.1121
# Epoch 62/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1130 - val_loss: 0.1119
# Epoch 63/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1129 - val_loss: 0.1119
# Epoch 64/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1128 - val_loss: 0.1118
# Epoch 65/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1128 - val_loss: 0.1118
# Epoch 66/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1127 - val_loss: 0.1117
# Epoch 67/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1126 - val_loss: 0.1116
# Epoch 68/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1126 - val_loss: 0.1116
# Epoch 69/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1125 - val_loss: 0.1115
# Epoch 70/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1124 - val_loss: 0.1115
# Epoch 71/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1124 - val_loss: 0.1112
# Epoch 72/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1123 - val_loss: 0.1113
# Epoch 73/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1122 - val_loss: 0.1112
# Epoch 74/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1122 - val_loss: 0.1112
# Epoch 75/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1121 - val_loss: 0.1115
# Epoch 76/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1120 - val_loss: 0.1114
# Epoch 77/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1119 - val_loss: 0.1112
# Epoch 78/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1119 - val_loss: 0.1109
# Epoch 79/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1118 - val_loss: 0.1109
# Epoch 80/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1118 - val_loss: 0.1107
# Epoch 81/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1117 - val_loss: 0.1109
# Epoch 82/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1116 - val_loss: 0.1107
# Epoch 83/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1116 - val_loss: 0.1108
# Epoch 84/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1115 - val_loss: 0.1106
# Epoch 85/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1114 - val_loss: 0.1104
# Epoch 86/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1114 - val_loss: 0.1104
# Epoch 87/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1113 - val_loss: 0.1103
# Epoch 88/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1113 - val_loss: 0.1103
# Epoch 89/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1112 - val_loss: 0.1101
# Epoch 90/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1111 - val_loss: 0.1103
# Epoch 91/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1111 - val_loss: 0.1100
# Epoch 92/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1110 - val_loss: 0.1100
# Epoch 93/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1110 - val_loss: 0.1104
# Epoch 94/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1109 - val_loss: 0.1099
# Epoch 95/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1108 - val_loss: 0.1099
# Epoch 96/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1108 - val_loss: 0.1098
# Epoch 97/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1107 - val_loss: 0.1096
# Epoch 98/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1107 - val_loss: 0.1098
# Epoch 99/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1106 - val_loss: 0.1097
# Epoch 100/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1106 - val_loss: 0.1096
# Epoch 101/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1105 - val_loss: 0.1096
# Epoch 102/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1105 - val_loss: 0.1095
# Epoch 103/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1105 - val_loss: 0.1097
# Epoch 104/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1104 - val_loss: 0.1096
# Epoch 105/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1104 - val_loss: 0.1093
# Epoch 106/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1103 - val_loss: 0.1094
# Epoch 107/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1103 - val_loss: 0.1094
# Epoch 108/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1102 - val_loss: 0.1092
# Epoch 109/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1102 - val_loss: 0.1092
# Epoch 110/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1101 - val_loss: 0.1092
# Epoch 111/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1101 - val_loss: 0.1090
# Epoch 112/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1101 - val_loss: 0.1090
# Epoch 113/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1100 - val_loss: 0.1092
# Epoch 114/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1100 - val_loss: 0.1089
# Epoch 115/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1099 - val_loss: 0.1090
# Epoch 116/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1099 - val_loss: 0.1089
# Epoch 117/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1098 - val_loss: 0.1088
# Epoch 118/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1098 - val_loss: 0.1087
# Epoch 119/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1097 - val_loss: 0.1093
# Epoch 120/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1097 - val_loss: 0.1088
# Epoch 121/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1097 - val_loss: 0.1087
# Epoch 122/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1096 - val_loss: 0.1090
# Epoch 123/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1096 - val_loss: 0.1087
# Epoch 124/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1096 - val_loss: 0.1086
# Epoch 125/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1095 - val_loss: 0.1086
# Epoch 126/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1095 - val_loss: 0.1085
# Epoch 127/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1094 - val_loss: 0.1086
# Epoch 128/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1094 - val_loss: 0.1084
# Epoch 129/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1094 - val_loss: 0.1085
# Epoch 130/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1093 - val_loss: 0.1084
# Epoch 131/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1093 - val_loss: 0.1084
# Epoch 132/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1093 - val_loss: 0.1084
# Epoch 133/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1092 - val_loss: 0.1084
# Epoch 134/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1092 - val_loss: 0.1085
# Epoch 135/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1091 - val_loss: 0.1083
# Epoch 136/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1091 - val_loss: 0.1084
# Epoch 137/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1091 - val_loss: 0.1082
# Epoch 138/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1091 - val_loss: 0.1082
# Epoch 139/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1090 - val_loss: 0.1083
# Epoch 140/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1090 - val_loss: 0.1082
# Epoch 141/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1090 - val_loss: 0.1081
# Epoch 142/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1089 - val_loss: 0.1081
# Epoch 143/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1089 - val_loss: 0.1081
# Epoch 144/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1089 - val_loss: 0.1079
# Epoch 145/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1088 - val_loss: 0.1080
# Epoch 146/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1088 - val_loss: 0.1079
# Epoch 147/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1088 - val_loss: 0.1078
# Epoch 148/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1087 - val_loss: 0.1078
# Epoch 149/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1087 - val_loss: 0.1080
# Epoch 150/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1087 - val_loss: 0.1080
# Epoch 151/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1086 - val_loss: 0.1077
# Epoch 152/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1086 - val_loss: 0.1078
# Epoch 153/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1086 - val_loss: 0.1077
# Epoch 154/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1085 - val_loss: 0.1076
# Epoch 155/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1085 - val_loss: 0.1077
# Epoch 156/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1085 - val_loss: 0.1077
# Epoch 157/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1085 - val_loss: 0.1077
# Epoch 158/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1084 - val_loss: 0.1076
# Epoch 159/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1084 - val_loss: 0.1075
# Epoch 160/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1084 - val_loss: 0.1076
# Epoch 161/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1083 - val_loss: 0.1074
# Epoch 162/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1083 - val_loss: 0.1076
# Epoch 163/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1083 - val_loss: 0.1074
# Epoch 164/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1083 - val_loss: 0.1074
# Epoch 165/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1082 - val_loss: 0.1074
# Epoch 166/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1082 - val_loss: 0.1074
# Epoch 167/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1082 - val_loss: 0.1073
# Epoch 168/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1081 - val_loss: 0.1072
# Epoch 169/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1081 - val_loss: 0.1073
# Epoch 170/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1081 - val_loss: 0.1072
# Epoch 171/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1081 - val_loss: 0.1073
# Epoch 172/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1081 - val_loss: 0.1072
# Epoch 173/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1080 - val_loss: 0.1072
# Epoch 174/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1080 - val_loss: 0.1071
# Epoch 175/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1080 - val_loss: 0.1071
# Epoch 176/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1079 - val_loss: 0.1072
# Epoch 177/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1079 - val_loss: 0.1072
# Epoch 178/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1079 - val_loss: 0.1070
# Epoch 179/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1079 - val_loss: 0.1073
# Epoch 180/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1078 - val_loss: 0.1069
# Epoch 181/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1078 - val_loss: 0.1069
# Epoch 182/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1078 - val_loss: 0.1069
# Epoch 183/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1078 - val_loss: 0.1068
# Epoch 184/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1077 - val_loss: 0.1069
# Epoch 185/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1077 - val_loss: 0.1069
# Epoch 186/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1077 - val_loss: 0.1068
# Epoch 187/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1077 - val_loss: 0.1068
# Epoch 188/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1076 - val_loss: 0.1068
# Epoch 189/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1076 - val_loss: 0.1069
# Epoch 190/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1076 - val_loss: 0.1070
# Epoch 191/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1076 - val_loss: 0.1066
# Epoch 192/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1075 - val_loss: 0.1068
# Epoch 193/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1075 - val_loss: 0.1066
# Epoch 194/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1075 - val_loss: 0.1067
# Epoch 195/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1075 - val_loss: 0.1066
# Epoch 196/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1074 - val_loss: 0.1068
# Epoch 197/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1074 - val_loss: 0.1065
# Epoch 198/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1074 - val_loss: 0.1066
# Epoch 199/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1074 - val_loss: 0.1066
# Epoch 200/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1073 - val_loss: 0.1066
# Epoch 201/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1073 - val_loss: 0.1066
# Epoch 202/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1073 - val_loss: 0.1067
# Epoch 203/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1073 - val_loss: 0.1067
# Epoch 204/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1072 - val_loss: 0.1064
# Epoch 205/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1072 - val_loss: 0.1064
# Epoch 206/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1072 - val_loss: 0.1065
# Epoch 207/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1072 - val_loss: 0.1065
# Epoch 208/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1072 - val_loss: 0.1065
# Epoch 209/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1071 - val_loss: 0.1064
# Epoch 210/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1071 - val_loss: 0.1063
# Epoch 211/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1071 - val_loss: 0.1063
# Epoch 212/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1071 - val_loss: 0.1064
# Epoch 213/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1071 - val_loss: 0.1062
# Epoch 214/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1070 - val_loss: 0.1063
# Epoch 215/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1070 - val_loss: 0.1062
# Epoch 216/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1070 - val_loss: 0.1061
# Epoch 217/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1070 - val_loss: 0.1062
# Epoch 218/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1069 - val_loss: 0.1063
# Epoch 219/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1069 - val_loss: 0.1061
# Epoch 220/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1069 - val_loss: 0.1061
# Epoch 221/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1069 - val_loss: 0.1062
# Epoch 222/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1069 - val_loss: 0.1066
# Epoch 223/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1068 - val_loss: 0.1061
# Epoch 224/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1068 - val_loss: 0.1060
# Epoch 225/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1068 - val_loss: 0.1061
# Epoch 226/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1068 - val_loss: 0.1061
# Epoch 227/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1068 - val_loss: 0.1061
# Epoch 228/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1067 - val_loss: 0.1062
# Epoch 229/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1067 - val_loss: 0.1059
# Epoch 230/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1067 - val_loss: 0.1059
# Epoch 231/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1067 - val_loss: 0.1059
# Epoch 232/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1066 - val_loss: 0.1058
# Epoch 233/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1066 - val_loss: 0.1059
# Epoch 234/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1066 - val_loss: 0.1058
# Epoch 235/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1066 - val_loss: 0.1057
# Epoch 236/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1066 - val_loss: 0.1058
# Epoch 237/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1065 - val_loss: 0.1060
# Epoch 238/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1065 - val_loss: 0.1059
# Epoch 239/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1065 - val_loss: 0.1058
# Epoch 240/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1065 - val_loss: 0.1059
# Epoch 241/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1065 - val_loss: 0.1058
# Epoch 242/400
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1064 - val_loss: 0.1056
# Epoch 243/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1064 - val_loss: 0.1058
# Epoch 244/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1064 - val_loss: 0.1057
# Epoch 245/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1064 - val_loss: 0.1058
# Epoch 246/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1064 - val_loss: 0.1057
# Epoch 247/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1064 - val_loss: 0.1059
# Epoch 248/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1063 - val_loss: 0.1057
# Epoch 249/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1063 - val_loss: 0.1058
# Epoch 250/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1063 - val_loss: 0.1056
# Epoch 251/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1063 - val_loss: 0.1056
# Epoch 252/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1062 - val_loss: 0.1057
# Epoch 253/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1062 - val_loss: 0.1055
# Epoch 254/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1062 - val_loss: 0.1054
# Epoch 255/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1062 - val_loss: 0.1053
# Epoch 256/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1062 - val_loss: 0.1056
# Epoch 257/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1062 - val_loss: 0.1054
# Epoch 258/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1061 - val_loss: 0.1057
# Epoch 259/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1061 - val_loss: 0.1054
# Epoch 260/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1061 - val_loss: 0.1054
# Epoch 261/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1061 - val_loss: 0.1053
# Epoch 262/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1061 - val_loss: 0.1054
# Epoch 263/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1061 - val_loss: 0.1053
# Epoch 264/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1060 - val_loss: 0.1052
# Epoch 265/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1060 - val_loss: 0.1052
# Epoch 266/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1060 - val_loss: 0.1052
# Epoch 267/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1060 - val_loss: 0.1053
# Epoch 268/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1059 - val_loss: 0.1055
# Epoch 269/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1059 - val_loss: 0.1051
# Epoch 270/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1059 - val_loss: 0.1053
# Epoch 271/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1059 - val_loss: 0.1053
# Epoch 272/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1059 - val_loss: 0.1052
# Epoch 273/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1059 - val_loss: 0.1057
# Epoch 274/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1058 - val_loss: 0.1054
# Epoch 275/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1058 - val_loss: 0.1051
# Epoch 276/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1058 - val_loss: 0.1053
# Epoch 277/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1058 - val_loss: 0.1050
# Epoch 278/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1058 - val_loss: 0.1051
# Epoch 279/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1057 - val_loss: 0.1050
# Epoch 280/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1057 - val_loss: 0.1052
# Epoch 281/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1057 - val_loss: 0.1050
# Epoch 282/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1057 - val_loss: 0.1049
# Epoch 283/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1057 - val_loss: 0.1050
# Epoch 284/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1057 - val_loss: 0.1055
# Epoch 285/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1057 - val_loss: 0.1053
# Epoch 286/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1056 - val_loss: 0.1049
# Epoch 287/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1056 - val_loss: 0.1049
# Epoch 288/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1056 - val_loss: 0.1049
# Epoch 289/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1056 - val_loss: 0.1050
# Epoch 290/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1056 - val_loss: 0.1050
# Epoch 291/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1056 - val_loss: 0.1048
# Epoch 292/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1055 - val_loss: 0.1049
# Epoch 293/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1055 - val_loss: 0.1049
# Epoch 294/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1055 - val_loss: 0.1048
# Epoch 295/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1055 - val_loss: 0.1048
# Epoch 296/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1055 - val_loss: 0.1049
# Epoch 297/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1054 - val_loss: 0.1049
# Epoch 298/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1054 - val_loss: 0.1047
# Epoch 299/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1054 - val_loss: 0.1048
# Epoch 300/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1054 - val_loss: 0.1049
# Epoch 301/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1054 - val_loss: 0.1048
# Epoch 302/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1054 - val_loss: 0.1049
# Epoch 303/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1054 - val_loss: 0.1046
# Epoch 304/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1053 - val_loss: 0.1047
# Epoch 305/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1053 - val_loss: 0.1048
# Epoch 306/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1053 - val_loss: 0.1046
# Epoch 307/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1053 - val_loss: 0.1049
# Epoch 308/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1053 - val_loss: 0.1046
# Epoch 309/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1052 - val_loss: 0.1045
# Epoch 310/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1052 - val_loss: 0.1046
# Epoch 311/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1052 - val_loss: 0.1045
# Epoch 312/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1052 - val_loss: 0.1046
# Epoch 313/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1052 - val_loss: 0.1047
# Epoch 314/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1052 - val_loss: 0.1046
# Epoch 315/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1052 - val_loss: 0.1044
# Epoch 316/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1051 - val_loss: 0.1044
# Epoch 317/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1051 - val_loss: 0.1046
# Epoch 318/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1051 - val_loss: 0.1044
# Epoch 319/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1051 - val_loss: 0.1045
# Epoch 320/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1051 - val_loss: 0.1044
# Epoch 321/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1051 - val_loss: 0.1045
# Epoch 322/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1050 - val_loss: 0.1046
# Epoch 323/400
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1050 - val_loss: 0.1043
# Epoch 324/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1050 - val_loss: 0.1044
# Epoch 325/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1050 - val_loss: 0.1044
# Epoch 326/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1050 - val_loss: 0.1044
# Epoch 327/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1050 - val_loss: 0.1044
# Epoch 328/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1050 - val_loss: 0.1043
# Epoch 329/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1049 - val_loss: 0.1044
# Epoch 330/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1049 - val_loss: 0.1043
# Epoch 331/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1049 - val_loss: 0.1043
# Epoch 332/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1049 - val_loss: 0.1043
# Epoch 333/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1049 - val_loss: 0.1042
# Epoch 334/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1049 - val_loss: 0.1045
# Epoch 335/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 336/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 337/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 338/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 339/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 340/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 341/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 342/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1048 - val_loss: 0.1043
# Epoch 343/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1048 - val_loss: 0.1042
# Epoch 344/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1047 - val_loss: 0.1040
# Epoch 345/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1047 - val_loss: 0.1041
# Epoch 346/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1047 - val_loss: 0.1043
# Epoch 347/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1047 - val_loss: 0.1041
# Epoch 348/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1047 - val_loss: 0.1041
# Epoch 349/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1046 - val_loss: 0.1039
# Epoch 350/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1046 - val_loss: 0.1041
# Epoch 351/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1046 - val_loss: 0.1040
# Epoch 352/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1046 - val_loss: 0.1040
# Epoch 353/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1046 - val_loss: 0.1041
# Epoch 354/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1046 - val_loss: 0.1040
# Epoch 355/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1046 - val_loss: 0.1039
# Epoch 356/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1046 - val_loss: 0.1040
# Epoch 357/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1045 - val_loss: 0.1040
# Epoch 358/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1045 - val_loss: 0.1040
# Epoch 359/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1045 - val_loss: 0.1040
# Epoch 360/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1045 - val_loss: 0.1040
# Epoch 361/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1045 - val_loss: 0.1040
# Epoch 362/400
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1045 - val_loss: 0.1041
# Epoch 363/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1045 - val_loss: 0.1038
# Epoch 364/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1044 - val_loss: 0.1039
# Epoch 365/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1044 - val_loss: 0.1039
# Epoch 366/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1044 - val_loss: 0.1038
# Epoch 367/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1044 - val_loss: 0.1039
# Epoch 368/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1044 - val_loss: 0.1039
# Epoch 369/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1044 - val_loss: 0.1039
# Epoch 370/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1043 - val_loss: 0.1038
# Epoch 371/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1043 - val_loss: 0.1039
# Epoch 372/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1043 - val_loss: 0.1040
# Epoch 373/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1043 - val_loss: 0.1040
# Epoch 374/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1043 - val_loss: 0.1038
# Epoch 375/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1043 - val_loss: 0.1038
# Epoch 376/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1043 - val_loss: 0.1038
# Epoch 377/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1043 - val_loss: 0.1038
# Epoch 378/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1038
# Epoch 379/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1042 - val_loss: 0.1040
# Epoch 380/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1037
# Epoch 381/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1036
# Epoch 382/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1038
# Epoch 383/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1042 - val_loss: 0.1037
# Epoch 384/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1042 - val_loss: 0.1037
# Epoch 385/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1036
# Epoch 386/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1042 - val_loss: 0.1038
# Epoch 387/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1041 - val_loss: 0.1036
# Epoch 388/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1041 - val_loss: 0.1038
# Epoch 389/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1041 - val_loss: 0.1035
# Epoch 390/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1041 - val_loss: 0.1036
# Epoch 391/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1041 - val_loss: 0.1036
# Epoch 392/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1041 - val_loss: 0.1035
# Epoch 393/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1040 - val_loss: 0.1035
# Epoch 394/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1040 - val_loss: 0.1037
# Epoch 395/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1040 - val_loss: 0.1034
# Epoch 396/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1040 - val_loss: 0.1035
# Epoch 397/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1040 - val_loss: 0.1034
# Epoch 398/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1040 - val_loss: 0.1036
# Epoch 399/400
# 600/600 [==============================] - 3s 4ms/step - loss: 0.1040 - val_loss: 0.1035
# Epoch 400/400
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1040 - val_loss: 0.1036

# %%
pl.plot(np.array(history16_overfit.history['loss']), label="training")
pl.plot(np.array(history16_overfit.history['val_loss']), label="validation")
pl.ylabel('loss')
pl.xlabel('iteration')
pl.legend()
#pl.yscale('log')
#pl.xscale('log')

output_image16_bce = model_digits16_bce.predict(x_test)
for i in range(10):
  compareinout(i, output_image64_bce, x_test)
# Out:
# 313/313 [==============================] - 0s 2ms/step

# %% [markdown]
# The loss function still decreases by the validation loss function is flat or increases: sign of overfitting - we are learning non-generalizable properties of the training set
