# %% [markdown]
# <a href="https://colab.research.google.com/github/massimocipressi/MLPNS_MCipressi/blob/main/MPLNS_17_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy as sp
from scipy import stats

# %%
url = "https://raw.githubusercontent.com/fedhere/MLPNS_FBianco/main/statistics/KStest/earthquakes.csv"

# %%
eqs = pd.read_csv(url,sep=" ") #notiamo che count è diverso

# %%
eqs.describe()

# %%
#ci interessa la frequenza in funzione della magnitudo
eqs.head()
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss  ET  GT MAG  Unnamed: 5  M  Unnamed: 7  Unnamed: 8  \
# 0  1984/01/01  01:30:57.52  eq NaN   l        2.02  c         NaN         NaN
# 1  1984/01/01  05:31:34.16  eq NaN   l        2.12  c         NaN         NaN
# 2  1984/01/01  06:59:05.14  eq NaN   l        2.43  c         NaN         NaN
# 3  1984/01/01  11:10:25.29  eq NaN   l        2.07  c         NaN         NaN
# 4  1984/01/01  19:38:19.79  eq NaN   l        2.13  c         NaN         NaN
#
#    Unnamed: 9  ...     Q  Unnamed: 25  EVID Unnamed: 27 Unnamed: 28  \
# 0      33.246  ...  17.0          NaN   NaN         NaN         NaN
# 1      32.945  ...  42.0          NaN   NaN         NaN         NaN
# 2      33.343  ...  30.0          NaN   NaN         NaN         NaN
# 3      33.668  ...   NaN          NaN   NaN         NaN         NaN
# 4      33.963  ...  49.0          NaN   NaN         NaN         NaN
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  NPH  NGRM
# ...

# %%
eqs.columns
# Out:
# Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG', 'Unnamed: 5', 'M',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'LAT', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'LON', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'DEPTH', 'Q', 'Unnamed: 25', 'EVID',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'NPH', 'NGRM'],
#       dtype='object')

# %%
eqs.rename({"#YYY/MM/DD":"date", "HH:mm:SS.ss":"time"},axis=1,inplace=True) #cambiamo i nomi alle colonne e applichiamo la modifica

# %%
eqs.head()
# Out:
#          date         time  ET  GT MAG  Unnamed: 5  M  Unnamed: 7  Unnamed: 8  \
# 0  1984/01/01  01:30:57.52  eq NaN   l        2.02  c         NaN         NaN
# 1  1984/01/01  05:31:34.16  eq NaN   l        2.12  c         NaN         NaN
# 2  1984/01/01  06:59:05.14  eq NaN   l        2.43  c         NaN         NaN
# 3  1984/01/01  11:10:25.29  eq NaN   l        2.07  c         NaN         NaN
# 4  1984/01/01  19:38:19.79  eq NaN   l        2.13  c         NaN         NaN
#
#    Unnamed: 9  ...     Q  Unnamed: 25  EVID Unnamed: 27 Unnamed: 28  \
# 0      33.246  ...  17.0          NaN   NaN         NaN         NaN
# 1      32.945  ...  42.0          NaN   NaN         NaN         NaN
# 2      33.343  ...  30.0          NaN   NaN         NaN         NaN
# 3      33.668  ...   NaN          NaN   NaN         NaN         NaN
# 4      33.963  ...  49.0          NaN   NaN         NaN         NaN
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  NPH  NGRM
# ...

# %%
#una funzione di pandas trasforma stringhe in date
pd.to_datetime("1984/01/01")
# Out:
# Timestamp('1984-01-01 00:00:00')

# %%
pd.to_datetime("1984/01/01"+" "+"01:30:57.52")
# Out:
# Timestamp('1984-01-01 01:30:57.520000')

# %%
eqs.date.map(pd.to_datetime) #noi però vogliamo anche l'ora quindi facciamo un for (inoltre alcune entrate creano problemi)
# Out:
# 0       1984-01-01
# 1       1984-01-01
# 2       1984-01-01
# 3       1984-01-01
# 4       1984-01-01
#            ...
# 70793   2002-12-29
# 70794   2002-12-29
# 70795   2002-12-29
# 70796   2002-12-30
# 70797   2002-12-30
# Name: date, Length: 70798, dtype: datetime64[ns]

# %%
eqs["datettime"]=pd.to_datetime(eqs.iloc[i]["date"]+" "+eqs.iloc[i]["time"])

# %%
for i in range(len(eqs)):
  #un problema sono i 60 secondi e non fino a 59
  if eqs.iloc[i]["time"].endswith("60.00"):
    eqs.iloc[i]["time"] = eqs.iloc[i]["time"].replace("60.00","59.99")
  pd.to_datetime(eqs.iloc[i]["date"]+" "+eqs.iloc[i]["time"]) #per prendere non una colonna ma un intero valore dobbiamo mettere iloc
